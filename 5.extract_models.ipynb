# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('df_processed_final.csv')
print(f"Dataset cargado: {df.shape}")
# Out:
# Dataset cargado: (1643, 95)

# %%
df.head(10)
# Out:
#    Genero  Campesino   Estrato  NIvel_educacion  Discapacidad  Tipo_formacion  \
# 0     1.0          0 -0.417790        -1.647467             0               0
# 1     0.0          0 -0.417790        -0.445477             0               0
# 2     0.0          1  0.751457         0.756512             0               0
# 3     0.0          0 -0.417790         0.155517             0               0
# 4     1.0          0 -0.417790        -1.647467             0               0
# 5     1.0          1 -1.587037         0.155517             0               0
# 6     1.0          0  0.751457         0.155517             0               0
# 7     1.0          0 -1.587037         0.155517             0               0
# 8     1.0          0 -0.417790         1.357507             0               0
# 9     1.0          1 -0.417790         0.756512             0               0
#
#    Victima_del_conflicto  tiempo_segundos  Puntaje_eje_tematico_selecionado  \
# 0                      0         0.270273                          0.808699
# 1                      0         0.231965                          0.368361
# 2                      0         0.802549                          0.189950
# 3                      0        -1.197521                         -0.003647
# 4                      0         0.811118                          0.747962
# 5                      0        -2.125981                         -1.787768
# 6                      0        -0.166739                          0.797309
# 7                      0         0.239021                          0.398729
# 8                      0         0.820695                          0.694818
# 9                      0         0.836825                          0.102641
#
#    area_1_alfabetizacion_datos  ...  Tipo_de_formacion_Híbrida  \
# 0                     0.410067  ...                          1
# 1                    -0.020334  ...                          0
# 2                     0.348581  ...                          0
# 3                    -0.143306  ...                          1
# 4                     0.041152  ...                          0
# 5                    -1.311539  ...                          0
# 6                     0.840469  ...                          1
# 7                     0.041152  ...                          0
# 8                    -0.266278  ...                          0
# 9                     0.410067  ...                          0
#
#    Tipo_de_formacion_Virtual  exito_academico  dia  mes  year  \
# 0                          0                1   16   12  2023
# 1                          1                0   18   12  2023
# 2                          1                0   18   12  2023
# 3                          0                1   17   12  2023
# 4                          1                0   16   12  2023
# 5                          1                0   18   12  2023
# 6                          0                1   16   12  2023
# 7                          1                1   17   12  2023
# 8                          1                1   16   12  2023
# 9                          1                1   18   12  2023
#
#    promedio_lineas  promedio_areas  ratio_asistencia   linea_pca
# 0        21.276790       24.142857             159.0   43.431065
# 1        18.419645       20.238095               0.0   18.004300
# 2        17.750000       19.571429              21.0   11.476016
# 3        16.678575       18.666667             159.0    2.323458
# 4        20.696430       23.380952              90.0   38.356090
# 5         3.196426        3.380952               0.0 -118.720758
# 6        21.098215       24.238095             159.0   41.727758
# 7        19.133930       21.285714             159.0   24.315387
# 8        21.008930       23.428571             156.0   41.283904
# 9        13.285715       14.571429             159.0  -29.135915
#
# [10 rows x 95 columns]
